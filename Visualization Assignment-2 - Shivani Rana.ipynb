# %% [markdown]
# # Visualization Assignment

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# ## Loading a dataset

# %%
iris = sns.load_dataset("iris")

# %% [markdown]
# ### The Iris dataset was used in R.A. Fisher's classic 1936 paper, The Use of Multiple Measurements in Taxonomic Problems, and can also be found on the UCI Machine Learning Repository.
#
# ### It includes three iris species with 50 samples each as well as some properties about each flower. One flower species is linearly separable from the other two, but the other two are not linearly separable from each other.
#
# ### Species of a flower is classified on the basis of sepal_length, sepal_width, petal_length and petal_width

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ## Q1 Plot Histograms using iris dataset

# %%
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn import datasets
iris = datasets.load_iris()

import pandas as pd
iris_df = pd.DataFrame(iris.data, columns = ['sepal_length','sepal_width','petal_length','petal_width'])
iris_df['target']=pd.Series(iris.target)
print(iris_df)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  target
# 0             5.1          3.5           1.4          0.2       0
# 1             4.9          3.0           1.4          0.2       0
# 2             4.7          3.2           1.3          0.2       0
# 3             4.6          3.1           1.5          0.2       0
# 4             5.0          3.6           1.4          0.2       0
# ..            ...          ...           ...          ...     ...
# 145           6.7          3.0           5.2          2.3       2
# 146           6.3          2.5           5.0          1.9       2
# 147           6.5          3.0           5.2          2.0       2
# 148           6.2          3.4           5.4          2.3       2
# 149           5.9          3.0           5.1          1.8       2
#
# [150 rows x 5 columns]

# %%
# Please write codes with observations

iris_df['sepal_length'].hist(bins=30)

# %%
iris_df['sepal_width'].hist(bins=30)

# %% [markdown]
# ## Q2 Plot Area Plot using iris dataset

# %%
# Please write codes with observations
plt.plot('sepal_length', linestyle='solid')
plt.plot('sepal_width', linestyle='dashed')
plt.plot('petal_length', linestyle='dashdot')
plt.plot('petal_width', linestyle='dotted')
plt.show()

# %% [markdown]
# ## Q3 Plot Densityplot using iris dataset

# %%
fig =plt.figure(figsize =(10,5))
ax = sns.kdeplot(x, shade=True, color="r")

# %% [markdown]
# ##### Please write codes with observations
# plt.figure(figsize=(10,))

# %% [markdown]
# ## Q4 Plot Histograms with Densityplot using iris dataset

# %%
fig =plt.figure(figsize =(10,5))
sns.set(); np.random.seed(0)
x = np.random.randn(100)
ax = sns.distplot(x)

# %% [markdown]
# ## Q5 Plot Boxplots using the iris dataset

# %%
# Please write codes with observations
sns.catplot(data=iris , kind='box' , height=10, aspect=2.5);

# %% [markdown]
# ## Q6 Plot Horizontal Boxplots using the iris dataset

# %%
# Please write codes with observations
sns.boxplot(data=data,orient='h')

# %%
#Ans 6
sns.boxplot(x='sepal_length',y='sepal_width',data=iris,orient='h')

# %% [markdown]
# ## Q7 Plot Violinplots using the iris dataset

# %%
# Please write codes with observations
sns.violinplot(x='sepal_length',y='sepal_width',data=iris)

# %% [markdown]
# ## Q8 Plot Horizontal Violinplots using the iris dataset

# %%
# Please write codes with observations
sns.violinplot(x='sepal_length',y='sepal_width',data=iris,orient='h')

# %% [markdown]
# ## Q9 Plot Bar Plot for the following dictionary

# %%
a_dictionary = {'apple': 10, 'orange': 15, 'lemon': 5, 'lime': 20}
keys = a_dictionary.keys()
values = a_dictionary.values()

plt.bar(keys, values)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ## Q10 Plot Scatter Plot for the following dictionary

# %%
data = {'apple': 10, 'orange': 15, 'lemon': 5, 'lime': 20}

# %%
# Please write your code with observations
a_dictionary = {'apple': 10, 'orange': 15, 'lemon': 5, 'lime': 20}
keys = a_dictionary.keys()
values = a_dictionary.values()

plt.scatter(keys, values, s=200 , marker = "^")

# %% [markdown]
# ## Q11 Plot Line Chart for the following dictionary

# %%
data = {'apple': 10, 'orange': 15, 'lemon': 5, 'lime': 20}

# %%
# Please write your code with observations
import matplotlib.pyplot as plt
data = {'apple': 10, 'orange': 15, 'lemon': 5, 'lime': 20}
plt.plot(data)  
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-f3c6ae30ebd9> in <module>
#       2 import matplotlib.pyplot as plt
#       3 data = {'apple': 10, 'orange': 15, 'lemon': 5, 'lime': 20}
# ----> 4 plt.plot(data)
#       5 plt.show()
#
# ~\Anaconda5\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2794     return gca().plot(
#    2795         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2796         is not None else {}), **kwargs)
#    2797
#    2798
#
# ~\Anaconda5\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
# -> 1667             self.add_line(line)
#    1668         self.autoscale_view(scalex=scalex, scaley=scaley)
#    1669         return lines
#
# ~\Anaconda5\lib\site-packages\matplotlib\axes\_base.py in add_line(self, line)
#    1900             line.set_clip_path(self.patch)
#    1901
# -> 1902         self._update_line_limits(line)
#    1903         if not line.get_label():
#    1904             line.set_label('_line%d' % len(self.lines))
#
# ~\Anaconda5\lib\site-packages\matplotlib\axes\_base.py in _update_line_limits(self, line)
#    1922         Figures out the data limit of the given line, updating self.dataLim.
#    1923         """
# -> 1924         path = line.get_path()
#    1925         if path.vertices.size == 0:
#    1926             return
#
# ~\Anaconda5\lib\site-packages\matplotlib\lines.py in get_path(self)
#    1025         """
#    1026         if self._invalidy or self._invalidx:
# -> 1027             self.recache()
#    1028         return self._path
#    1029
#
# ~\Anaconda5\lib\site-packages\matplotlib\lines.py in recache(self, always)
#     673         if always or self._invalidy:
#     674             yconv = self.convert_yunits(self._yorig)
# --> 675             y = _to_unmasked_float_array(yconv).ravel()
#     676         else:
#     677             y = self._y
#
# ~\Anaconda5\lib\site-packages\matplotlib\cbook\__init__.py in _to_unmasked_float_array(x)
#    1388         return np.ma.asarray(x, float).filled(np.nan)
#    1389     else:
# -> 1390         return np.asarray(x, float)
#    1391
#    1392
#
# ~\Anaconda5\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# TypeError: float() argument must be a string or a number, not 'dict'

# %% [markdown]
# ## Q12 Plot Scatter Plots using iris dataset

# %%
# Please write your code with observations
sns.scatterplot(x = 'petal_length', y = 'petal_width', data = iris_df)

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# ## Q13 Plot double Bar plot for the following data also add legends

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

# %%
# Please write your code with observations
import matplotlib.pyplot as plt
import numpy as np

labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
n_groups = 5

fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

rects1 = plt.bar(index, men_means, bar_width,
alpha=opacity,
color='g',
label='Men')

rects2 = plt.bar(index + bar_width, women_means, bar_width,
alpha=opacity,
color='r',
label='Women')

plt.xlabel('Person')
plt.ylabel('Scores')
plt.title('Scores by person')
plt.xticks(index + bar_width, ('G1', 'G2', 'G3', 'G4', 'G5'))
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Q14 Plot Pie Chart for the following data also add legends

# %%
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0)

# %%
# Please write your code with observations
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0)

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  

plt.show()

# %% [markdown]
# ## Q15 Plot KDE plots using the iris dataset

# %%
# Please write your code with observations

from sklearn import datasets 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline 
  
# Setting up the Data Frame 
iris = datasets.load_iris() 
  
iris_df = pd.DataFrame(iris.data, columns=['Sepal_Length', 
                      'Sepal_Width', 'Patal_Length', 'Petal_Width']) 
  
iris_df['Target'] = iris.target 
  
iris_df['Target'].replace([0], 'Iris_Setosa', inplace=True) 
iris_df['Target'].replace([1], 'Iris_Vercicolor', inplace=True) 
iris_df['Target'].replace([2], 'Iris_Virginica', inplace=True) 
  
# Plotting the KDE Plot 
sns.kdeplot(iris_df.loc[(iris_df['Target']=='Iris_Virginica'), 
            'Sepal_Length'], color='b', shade=True, Label='Iris_Virginica') 
  
# Setting the X and Y Label 
plt.xlabel('Sepal Length') 
plt.ylabel('Probability Density')
# Out:
# Text(0, 0.5, 'Probability Density')

# %% [markdown]
# ## Q16 Plot pair plots for the iris dataset

# %%
# Please write your code with observations
sns.pairplot(iris_df, hue="target");
plt.show()

# %% [markdown]
# ## Q17 Draw a scatterplot with marginal histograms using iris dataset

# %%
# Please write your code with observations

import numpy as np, pandas as pd; np.random.seed(0)
import seaborn as sns; sns.set(style="white", color_codes=True)
iris = sns.load_dataset("iris")
g = sns.jointplot(x="petal_length", y="petal_width", data=iris)

# %% [markdown]
# ## Q18 Replace the above scatterplots and histograms with density estimates and align the marginal Axes tightly with the joint Axes

# %%
# Please write your code with observations
g = sns.jointplot("petal_length", "petal_width", data=iris, kind="kde")

# %% [markdown]
# ## Q19 Plot Heatmap for iris dataset with correlations in it

# %%
# Please write your code with observations
data=sns.load_dataset("tips")
data.corr()
sns.heatmap(data.corr(),annot=True,cmap='RdBu')

# %% [markdown]
# ## Q20 Plot a 3D Scatterplot for iris dataset

# %%
# Please write your code with observations

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

x = iris['sepal_length']
y = iris['sepal_width']
z = iris['petal_length']

fig =plt.figure(figsize =(10,7))
ax = plt.axes(projection = '3d')

ax.scatter3D(x,y,z)
plt.title('Simple 3d Scatter plot')

plt.show()
